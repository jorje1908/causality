# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

from sklearn.cluster import KMeans 
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering
from pathlib import Path

# %%
import sys

sys.path.append('../../../src')

# %%
from base_exp_gen import generate_experiment as GEN_EXP
from clustering_algos import agglomerative_clustering, kmeans_clustering, box_clustering
from sklearn.model_selection import train_test_split as datasplit
from sklearn.ensemble import GradientBoostingRegressor as GDBR
from evaluations import computeATT_per_cluster as ATTC, predict_cf, calculate_ite, get_homogeneity, generate_paths,\
confusion_matrix

# %%
np.random.seed(seed = 0)

# %%
fonts = {'family': 'cmr10','weight': 'normal',
            'size': 20}    
div = 1

l1 = 22/div
l2 = 20/div
l3 = 13/(div-0.2)

mpl.rcParams['xtick.labelsize'] = l2
mpl.rcParams['ytick.labelsize'] = l2
mpl.rcParams['axes.labelsize'] = l1
mpl.rcParams['font.serif'] = 'Times New Roman'
mpl.rcParams['font.weight'] = 'normal'
mpl.rcParams['font.size'] = 20
mpl.rcParams['legend.fontsize'] = l3

#axes_font = {'labelsize':l1}
#mpl.rc('font', **font)
#xticks = {'labelsize':l2}# 'ytick.labelsize':20}
#yticks = {'labelsize':l2}# 'ytick.labelsize':20}
#legend = {'fontsize':l3}
# tex = {'usetex':True}
#mpl.rc('axes', **axes_font)
#mpl.rc('xtick', **xticks)
#mpl.rc('ytick', **yticks)
#mpl.rc('font', **fonts)
#mpl.rc('legend', **legend)

# %%
print(mpl.rcParams['xtick.labelsize'])
# Out:
# 20.0

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Generate Experiment

# %%
# %%time
path_figs = './figs/200kX/'
save = True
Path(path_figs).mkdir(exist_ok = True, parents = True)
# Out:
# CPU times: user 166 µs, sys: 150 µs, total: 316 µs
# Wall time: 518 µs

# %%
N,D = 2*10**5, 2
x = int((N)**(1/4))
clusters = x**2
print("Number of Clusters:{}, Number of Points:{}".format(clusters, N))
kw_generate =  {'N':N, 'D':D,'f_gen_name': 'uniform_gen','low':0, 'high': 1}
centers = [[0.5,0.5],[0.5,0.5]]
r_small = [0, 0.325735]
r_big = [0.325735,0.46065886]
eligibilities = [2,1]
kw_cluster =  {'f_class_name':'circle_class4', 'centers': centers,
               'eligibilities':eligibilities,'r_small': r_small, 'r_big':r_big}
kw_treatment = {'f_treat_name' :'uniform_treat','choices':[0,1], 'probabilities':[0.5,0.5]}

std = 2
stats = np.array([[1, std], [0, std], [0, std], [1, std],[1, std],
                  [2, std]])
kw_outcome = {'f_outcome_name': 'outcome1','treatment':'Treatment', 'cls':'C', 'stats':stats}

data = GEN_EXP(kw_generate, kw_cluster, kw_treatment, kw_outcome).dat
data = calculate_ite(data.copy(), treatment = 'Treatment',
                     counterfactual = 'Ycf', outcome = 'Y', ite_name = 'ITE')
# Out:
# Number of Clusters:441, Number of Points:200000

# %%
data.head(5)
# Out:
#          x0        x1  C  Treatment         Y       Ycf       ITE
# 0  0.548814  0.715189  2          0  2.158258  1.271538 -0.886720
# 1  0.602763  0.544883  2          1  1.402833 -1.887013  3.289846
# 2  0.423655  0.645894  2          0  0.332137 -1.008270 -1.340407
# 3  0.437587  0.891773  1          1  1.573929  1.498032  0.075897
# 4  0.963663  0.383442  0          0  2.867530  0.983962 -1.883568

# %%
data.describe()
# Out:
#                   x0             x1              C      Treatment  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.499785       0.499334       0.998640       0.501805
# std         0.288533       0.289177       0.815452       0.499998
# min         0.000003       0.000003       0.000000       0.000000
# 25%         0.249671       0.247699       0.000000       0.000000
# 50%         0.501024       0.498865       1.000000       1.000000
# 75%         0.749132       0.750450       2.000000       1.000000
# max         0.999990       0.999999       2.000000       1.000000
#
#                    Y            Ycf            ITE
# count  200000.000000  200000.000000  200000.000000
# mean        0.831767       0.834987       1.004660
# std         2.116324       2.112976       2.933779
# min        -9.004597      -8.790907     -11.390061
# 25%        -0.599254      -0.595259      -0.970363
# 50%         0.837300       0.831384       0.998771
# 75%         2.265152       2.262588       2.975021
# max        10.433324       9.855814      14.632811

# %%
#mpl.style.use(['seaborn-paper'])
#mpl.rcParams.update(mpl.rcParamsDefault)

# %%
fig, ax = plt.subplots()

ax.scatter(data['x0'].values, data['x1'].values, c=data['C'].values, cmap = 'Greys', s=0.1)

if save:
    fig.savefig(path_figs+'data.jpeg',bbox_inches='tight', pad_inches = 0)

plt.show()

# %%
from econml.metalearners import XLearner as XL
from sklearn.ensemble import RandomForestClassifier as RF
# Out:
# /home/mavrog2/.conda/envs/jorje/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %% [markdown]
# ### Train X learner to directly calculate effect
# #### Use gradient boosting trees for estimation models and  loistic Regression for Rest

# %%
# %%time
f1_kwargs = {'n_estimators':400, 'max_depth':18}
f2_kwargs = {'n_estimators':400, 'max_depth':18}

m0 = GDBR(**f1_kwargs)
m1 = GDBR(**f1_kwargs)
t0 = GDBR(**f1_kwargs)
t1 = GDBR(**f1_kwargs)

model = XL((m0,m1), (t0,t1), categories=[0,1])
xml = model.fit(data.Y, data.Treatment, X = data[['x0','x1']])
# Out:
# CPU times: user 15min 20s, sys: 402 ms, total: 15min 21s
# Wall time: 15min 19s

# %% [markdown]
# ### Get Xlearner Effects and add it as a column to the data

# %%
data['ITE-XML'] = xml.effect(data[['x0','x1']])
print(data['ITE-XML'].min(), data['ITE-XML'].max())
# Out:
# -7.993829350446884 6.147035606950668

# %% [markdown]
# ### Xlearner Effect histogram

# %%
path2 = path_figs+'histograms/'
Path(path2).mkdir(exist_ok = True)


fig, ax = plt.subplots()

bins = 400
ax = sns.distplot(data['ITE-XML'],  bins=bins, kde = False,ax = ax)
ax.set_xlabel('ITE-XLEARNER')
ax.set_xlim(-5,7)
if save:
    fig.savefig(path2+'xlearnhist.pdf', bbox_inches='tight',pad_inches = 0)
# Out:
# /home/mavrog2/.conda/envs/jorje/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 3Clustering of Xlearner effects

# %%
cluster_name = 'ITE-XML-3Clust'
col = 'ITE-XML'
filt1 = data[col] <= 0.5
filt2 = data[col] >= 0.5
filt3 = data[col] >= 1.5

data[cluster_name] = 0
data.loc[filt1,cluster_name] = 0
data.loc[filt2, cluster_name] = 1
data.loc[filt3, cluster_name] = 2


#data,_ = kmeans_clustering(data, clusters = 3, cluster_name = 'ITE-XML-3Clust',col_select = ['ITE-XML'] )

# %%
path3 = path_figs+'reconstruction/'
Path(path3).mkdir(exist_ok = True, parents = True)

fig, ax = plt.subplots()

sc = ax.scatter(data['x0'].values, data['x1'].values, c=data['ITE-XML-3Clust'], cmap = 'Greys', s = 1)
if save:
        ax.set_aspect('equal', adjustable='box')
        fig.savefig(path3+'{}.jpeg'.format('ITE-XML-3Clust'), bbox_inches='tight',pad_inches = 0)

# %% [markdown]
# ### Xlearner 3Clustering mean absolute error versu eligibility

# %%
def MAE_pd(group, name1,name2,column_name):
    
    group[column_name] = np.abs(group[name1].values-group[name2].mean())
    return group

# %%
ite_column = 'ITE-XML'
clust2 = 'ITE-XML-3Clust'
data = data.groupby(clust2).apply(lambda x: MAE_pd(x, 'C', ite_column, clust2+'-err-GDBR'))

# %%
errors = data.describe().loc[['mean', 'std'], [col for col in data.columns if 'err' in col]].T

# %%
errors
# Out:
#                              mean       std
# ITE-XML-3Clust-err-GDBR  0.559495  0.555727

# %%
from IPython.display import display

path4 = path_figs+'matrices/'
Path(path4).mkdir(exist_ok = True)

mat = confusion_matrix(data, 'C', 'ITE-XML-3Clust', 3, save = save, save_dir = path4)
display(mat)
# Out:
#           C0 Pred   C1 Pred   C2 Pred
# C0 True  0.685301  0.231195  0.083503
# C1 True  0.243508  0.511551  0.244941
# C2 True  0.023162  0.185639  0.791200

# %%
data.groupby('ITE-XML-3Clust').mean()
# Out:
#                       x0        x1         C  Treatment         Y       Ycf  \
# ITE-XML-3Clust
# 0               0.502747  0.497320  0.305288   0.503314  0.869595  0.872274
# 1               0.493468  0.503138  0.950227   0.502193  0.726163  0.735069
# 2               0.502517  0.497886  1.630228   0.500195  0.887419  0.886366
#
#                      ITE   ITE-XML  ITE-XML-3Clust-err-GDBR
# ITE-XML-3Clust
# 0              -0.754985 -0.379078                 0.684366
# 1               0.922425  1.011161                 0.453873
# 2               2.573732  2.171158                 0.540930

# %%
np.mean(np.abs(data['C'] - data['ITE-XML'])), np.std(np.abs(data['C'] - data['ITE-XML']))
# Out:
# (0.6596062401502463, 0.5980467028350901)
